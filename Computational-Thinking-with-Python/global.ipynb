# %% [markdown]
# back end

# %%
# importando as bibliotecas necessárias
import pandas as pd
import random
from datetime import datetime

# %%
# criando um dicionário para salvar os cadastros 
cadastros = {
    "Nome do paciente":[],
    "CPF do paciente":[],
    "Email do paciente":[],
    "Senha do paciente":[],
    "Telefone do paciente":[]
}

# %%
# criando função para cadastrar pacientes
def cadastrar_paciente():
# criando inputs com nome, cpf, email, senha e telefone
    nome = input("Insira o nome do paciente")
    cpf = input("Insira o CPF do paciente")
    email = input("Insira o e-mail do paciente")
    senha = input("Insira a senha do paciente")
    telefone = input("Insira o telefone do paciente")
# criando estrutura if else que verifica se o cpf cadastrado já está contido no dicionário de cadastros
    if cpf not in cadastros["CPF do paciente"]:
# caso o cpf inserido não esteja contido no dicionário, adicione todos os inputs do usuário no dicionário        
        cadastros["Nome do paciente"].append(nome)
        cadastros["CPF do paciente"].append(cpf)
        cadastros["Email do paciente"].append(email)
        cadastros["Senha do paciente"].append(senha)
        cadastros["Telefone do paciente"].append(telefone)
# caso contrário, imprima uma mensagem indicando que o paciente já está cadastrado        
    else:
        print("\nEsse CPF já está cadastrado \n Faça o login para continuar")

# chamando a função cadastrar_paciente        
cadastrar_paciente()

# criando nova variável chamada df_cadastros que usa a biblioteca importada para imprimir os dados contidos no dicionário cadastro
df_cadastros = pd.DataFrame(cadastros)

#chamando a variável criada no passo anterior
df_cadastros
# Out:
#   Nome do paciente CPF do paciente Email do paciente Senha do paciente  \
# 0                a               1                 a                 a
# 1                b               2                 b                 b
# 2                c               3                 c                 c
# 3                d               4                 d                 d
# 4                e               5                 e                 e
#
#   Telefone do paciente
# 0                    1
# 1                    2
# 2                    3
# 3                    1
# 4                    2

# %% [markdown]
# o que o paciente vê

# %%
# criando uma lista vazia para salvar o nome do paciente
paciente = []
# criando uma função para que o paciente efetue login usando email e senha
def login_paciente():
    login = input("Digite o seu email")
    senha = input("Digite sua senha")
# caso o email e senha inseridos pelo paciente estejam cadastrados:
    if login in cadastros["Email do paciente"] and senha in cadastros["Senha do paciente"]:
# imprimindo uma mensagem que indica que o login foi um sucesso
        print("Login efetuado com sucesso!")
# salvando o indice do email do paciente em uma variável index         
        index = cadastros["Email do paciente"].index(login)
# salvando o nome que partilha o mesmo indice no dicionário cadastros na lista vazia paciente        
        paciente.append(cadastros["Nome do paciente"][index])
# imprimindo uma mensagem de boas vindas para o paciente        
        print(f"Bem vindo {paciente[0]}!")
# caso contrário:
    else:
# imprimindo a mensagem "Usuário ou Senha inválido."         
        print("Usuário ou Senha inválido.")  

# chamando a função login_paciente               
login_paciente() 
# criando uma variável paciente_logado que salva o nome inserido pela função login_paciente na lista paciente
paciente_logado = paciente[0]
# Out:
# Usuário ou Senha inválido.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\batma\Desktop\global solution\global-solution-1ESPA-2023\Computational-Thinking-with-Python\global.ipynb Cell 6 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/batma/Desktop/global%20solution/global-solution-1ESPA-2023/Computational-Thinking-with-Python/global.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a>         print("Usuário ou Senha inválido.")
#      <a href='vscode-notebook-cell:/c%3A/Users/batma/Desktop/global%20solution/global-solution-1ESPA-2023/Computational-Thinking-with-Python/global.ipynb#W3sZmlsZQ%3D%3D?line=22'>23</a> login_paciente()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/batma/Desktop/global%20solution/global-solution-1ESPA-2023/Computational-Thinking-with-Python/global.ipynb#W3sZmlsZQ%3D%3D?line=23'>24</a> paciente_logado = paciente[0]
#
# IndexError: list index out of range

# %%
# criando um segundo dicionário para salvar os prontuários dos pacientes
prontuarios = {
    "Paciente":[],
    "Data de acesso":[],
    "Sintomas":[],
    "Medicamentos":[],
    "Alergias":[],
    "Doenças":[],
}

# %%
# criando uma função para registrar prontuários dos pacientes logados
def prontuario():
# usando biblioteca importada para salvar a data e hora em que foi preenchido o prontuário
    dia_e_horas = datetime.now()
    leitura_dia_e_horas = dia_e_horas.strftime("%d/%m/%Y %H:%M:%S")
# criando campos para que o paciente especifique os detalhes do prontuário
    sintomas = input("Quais sintomas você notou? Quando começaram os sintomas? Descreva de maneira detalhada")
    medicamentos = input("Faz uso de medicamentos? Se sim, quais?")
    alergias = input("Possui alergias? Se sim, quais?")
    doencas = input("Está fazendo tratamento de alguma doença? Se sim, quais?")
# adicionando os dados do prontuário ao dicionário prontuários    
    prontuarios["Paciente"].append(paciente_logado)
    prontuarios["Data de acesso"].append(leitura_dia_e_horas)
    prontuarios["Sintomas"].append(sintomas)
    prontuarios["Medicamentos"].append(medicamentos)
    prontuarios["Alergias"].append(alergias)
    prontuarios["Doenças"].append(doencas)

# chamando a função prontuario
prontuario()
# criando nova variável chamada df_prontuario que usa a biblioteca importada para imprimir os dados contidos no dicionário prontuario
df_prontuario = pd.DataFrame(prontuarios)
# chamando a variável criada no passo anterior
df_prontuario
# Out:
#   Paciente       Data de acesso Sintomas Medicamentos Alergias Doenças
# 0        a  28/11/2023 06:10:55
# 1        a  28/11/2023 06:11:01        .            .        .       .
# 2        b  28/11/2023 06:11:23
# 3        c  28/11/2023 06:11:38                     c        c       c

# %%
# criando função que permita ao paciente acessar seus prontuários
def prontuarios_do_paciente():
    paciente_desejado = input("Qual paciente você deseja verificar?")
    if paciente_desejado in prontuarios["Paciente"]:
        index = prontuarios["Paciente"].index(paciente_desejado)
        display(df_prontuario.iloc[index])
    else:
        print('Não foi encontrado o paciente solicitado')
prontuarios_do_paciente()
# Out:
# Paciente                            a
# Data de acesso    28/11/2023 06:10:55
# Sintomas
# Medicamentos
# Alergias
# Doenças
# Name: 0, dtype: object
